# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadUsmanManzoor/MLAlgorithms/blob/main/NN_Regression_backpropagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns=['cgpa','profile_score','lpa'])

# %%
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
def initialize_parameters(layer_dims):
  np.random.seed(3)
  parameters={}
  L= len(layer_dims)
  for l in range (1,L):

    parameters['W'+str(l)]= np.ones((layer_dims[l-1],layer_dims[l]))*0.1
    parameters['b'+str(l)]= np.zeros((layer_dims[l],1))

  return parameters

# %%
initialize_parameters([2,2,1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev,W,b):

  Z = np.dot(W.T, A_prev) + b

  return Z

# %%
from numpy.random import pareto
from inspect import AGEN_CLOSED

def L_layer_forward(X, parameters):

  A = X
  L = len(parameters)

  for l in range(1,L):
    A_prev = A
    Wl = parameters['W'+ str(l)]
    bl = parameters['b'+str(l)]
    print("A"+str(l-1)+": ",A_prev)
    print("W"+str(l)+": ",Wl)
    print("b"+str(l)+": ",bl)
    print("--"*20)

    A = linear_forward(A_prev,Wl,bl)
    print("A"+str(l)+": ", A)
    print("**"*20)
  return A,A_prev

# %%
x = df[['cgpa','profile_score']].values[0].reshape(2,1)
y = df[['lpa']].values[0][0]

Parameters= initialize_parameters([2,2,1])

L_layer_forward(x,Parameters)
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ****************************************
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ****************************************
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_21063/485069687.py in <cell line: 0>()
#       4 Parameters= initialize_parameters([2,2,1])
#       5
# ----> 6 L_layer_forward(x,Parameters)
#
# /tmp/ipykernel_21063/996086110.py in L_layer_forward(X, parameters)
#       9   for l in range(1,L):
#      10     A_prev = A
# ---> 11     Wl = parameters['W'+ str(l)]
#      12     bl = parameters['b'+str(l)]
#      13     print("A"+str(l-1)+": ",A_prev)
#
# KeyError: 'W3'

# %%
y
